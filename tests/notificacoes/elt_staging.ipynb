# %% [markdown]
# # ELT

# %%
import pandas as pd
from datetime import datetime 
import requests
from io import StringIO
import urllib3

# %%
# Mostra todas as colunas, sem limite
pd.set_option('display.max_columns', None)

# (Opcional) Ajustes que costumam ajudar:
pd.set_option('display.expand_frame_repr', False)   # evita quebra de linha
pd.set_option('display.max_colwidth', None)         # mostra o conteúdo completo das células
pd.set_option('display.width', 0)                   # usa toda a largura do notebook

# %%
layer ='01_staging'
dataset = 'notificacoes'
ts = datetime.now().strftime("%Y_%m_%d_%H_%M_%S") #'2025_06_30_14_17_00'
output = "/Users/silmara.barnabe/Desktop/Projects/vigimed/data/"+layer+"/"+dataset+"/"+ts+".parquet"
print(output)
# Out:
# /Users/silmara.barnabe/Desktop/Projects/vigimed/data/01_staging/notificacoes/2025_08_14_11_13_31.parquet

# %% [markdown]
# # Input

# %%
# desativa warnings de SSL
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

url = "https://dados.anvisa.gov.br/dados/VigiMed_Notificacoes.csv"

resp = requests.get(url, verify=False)
data = StringIO(resp.text)

df = pd.read_csv(
    data,
    sep=';',
    encoding='latin-1',
    dtype=str,
    quoting=3,  # csv.QUOTE_NONE
    on_bad_lines='error',
    low_memory=False
)

# %%
df.head().T
# Out:
#                                                                         0                                              1                       2                                              3                                              4
# UF                                                                     SP                                             SP                      SP                                             SP                                             SP
# TIPO_ENTRADA_VIGIMED                               Empresas Farmacęuticas                         Empresas Farmacęuticas  Empresas Farmacęuticas                         Empresas Farmacęuticas                         Empresas Farmacęuticas
# RECEBIDO_DE                                          Empresa Farmacęutica                           Empresa Farmacęutica    Empresa Farmacęutica                           Empresa Farmacęutica                           Empresa Farmacęutica
# IDENTIFICACAO_NOTIFICACAO                             BR-ANVISA-300212656                            BR-ANVISA-300208322     BR-ANVISA-300214015                            BR-ANVISA-300212385                            BR-ANVISA-300212764
# DATA_INCLUSAO_SISTEMA                                            20230928                                       20230901                20231006                                       20230927                                       20230929
# DATA_ULTIMA_ATUALIZACAO                                          20230928                                       20230901                20231006                                       20230927                                       20230929
# DATA_NOTIFICACAO                                                      NaN                                            NaN                     NaN                                            NaN                                            NaN
# TIPO_NOTIFICACAO                                   Notificaçăo espontânea                         Notificaçăo espontânea  Notificaçăo espontânea                         Notificaçăo espontânea                         Notificaçăo espontânea
# NOTIFICACAO_PARENT_CHILD                                              NaN                                            NaN                     NaN                                            NaN                                            NaN
# DATA_NASCIMENTO                                                  19900131                                            NaN                19710522                                            NaN                                       19820505
# IDADE_MOMENTO_REACAO                                               30 ano                                            NaN                  49 ano                                            NaN                                         39 ano
# GRUPO_IDADE                                                           NaN                                            NaN                     NaN                                            NaN                                            NaN
# IDADE_GESTACIONAL_MOMENTO_REACAO                                      NaN                                            NaN                     NaN                                            NaN                                            NaN
# SEXO                                                             Feminino                                       Feminino               Masculino                                      Masculino                                      Masculino
# GESTANTE                                                             Năo                                            Năo                     Năo                                            Năo                                            Năo
# LACTANTE                                                             Năo                                            Năo                     Năo                                            Năo                                            Năo
# PESO_KG                                                              68.0                                            NaN                     NaN                                            NaN                                            NaN
# ALTURA_CM                                                             165                                            NaN                     NaN                                            NaN                                            NaN
# REACAO_EVENTO_ADVERSO_MEDDRA                                  Hemiparesia                                       Cefaleia            Nefrolitíase                                 Abscesso nasal            Descompensaçăo metabólica diabética
# GRAVE                                                                 Sim                                            Năo                     Sim                                            Sim                                            Sim
# GRAVIDADE                         Outro efeito clinicamente significativo        Outro efeito clinicamente significativo          Hospitalizaçăo        Outro efeito clinicamente significativo        Outro efeito clinicamente significativo
# DESFECHO                                                       Recuperado                                   Desconhecido            Desconhecido                                   Desconhecido                                   Desconhecido
# DATA_INICIO_HORA                                                 20210125                                      20210122                20210203                                             NaN                                            NaN
# DATA_FINAL_HORA                                                  20210206                                            NaN                     NaN                                            NaN                                            NaN
# DURACAO                                                            12 dia                                            NaN                     NaN                                            NaN                                            NaN
# RELACAO_MEDICAMENTO_EVENTO                                   Concomitante                                       Suspeito            Concomitante                                       Suspeito                                       Suspeito
# NOME_MEDICAMENTO_WHODRUG                                           Tamisa                                      CoronaVac              Metformina          Vacina adsorvida COVID-19 (inativada)                                      CoronaVac
# ACAO_ADOTADA                                                Năo aplicável                                  Năo aplicável                     NaN                                            NaN                                   Desconhecido
# NOTIFICADOR                                                        Médico  Consumidor ou outro năo profissional de saúde                  Médico  Consumidor ou outro năo profissional de saúde  Consumidor ou outro năo profissional de saúde

# %% [markdown]
# # Output

# %%
df.to_parquet(output, compression="snappy", index=False)
